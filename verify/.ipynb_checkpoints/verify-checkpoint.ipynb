# %%
import numpy as np
import pandas as pd
import pickle

# %%
d1_list = pickle.load(open('../saved_datasets/3-11-19.stitch.aggregate.clip.simple_validation_split.enrich1.features1.features2.features3.features4.data_output_1.dateback=12.targ_enc_perm=8/xtrain_xtest_ytrain_ytest.pickle','rb'))
d2_list = pickle.load(open('../saved_datasets/3-11-19.stitch.aggregate.clip.simple_validation_split.enrich1.features1.features2.features3.features4.data_output_1.dateback=12.targ_enc_perm=8/xtrain_xtest_ytrain_ytest_(rerun).pickle','rb'))

# %%
def eq_df(x1,x2):
    return x1.equals(x2)

# %%
[eq_df(x1,x2) for x1,x2 in zip(d1_list[0],d2_list[0])]
# Out:
# [True, True]

# %%
[eq_df(x1,x2) for x1,x2 in zip(d1_list[1],d2_list[1])]
# Out:
# [True, True]

# %%
[eq_df(x1,x2) for x1,x2 in zip(d1_list[2],d2_list[2])]
# Out:
# [True, True]

# %%
[eq_df(x1,x2) for x1,x2 in zip(d1_list[3],d2_list[3])]
# Out:
# [True, True]

# %%
d1_list[0][1]
# Out:
#         date_block_num  shop_id  item_id  item_category_id  \
# 0                   33        5     5037              19.0
# 1                   33        5     5320               0.0
# 2                   33        5     5233              19.0
# 3                   33        5     5232              23.0
# 4                   33        5     5268               0.0
# 5                   33        5     5039              23.0
# 6                   33        5     5041              20.0
# 7                   33        5     5046              55.0
# 8                   33        5     5319              55.0
# 9                   33        5     5003               0.0
# 10                  33        5     4806              30.0
# 11                  33        5     4843              20.0
# 12                  33        5     4607              55.0
# 13                  33        5     4869              22.0
# 14                  33        5     4870              23.0
# ...
