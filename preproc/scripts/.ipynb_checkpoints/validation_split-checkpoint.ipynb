# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn import model_selection

# %%
train2 = pd.read_csv('../../gen_data/train2.csv')
test0py = pd.read_csv('../../original_data/test.csv.gz')

# %%
train2.dtypes
# Out:
# date_block_num         int64
# shop_id                int64
# item_id                int64
# item_category_id       int64
# shop_name             object
# item_name             object
# item_category_name    object
# sales                  int64
# dtype: object

# %%
#im sure theres a better way of doing this
train2['date_block_num'] =   pd.Series(train2['date_block_num'],dtype=np.int32)
train2['shop_id'] =          pd.Series(train2['shop_id'],dtype=np.int32)
train2['item_id'] =          pd.Series(train2['item_id'],dtype=np.int32)
train2['item_category_id'] = pd.Series(train2['item_category_id'],dtype=np.int32)
train2['sales'] =            pd.Series(train2['sales'],dtype=np.int32)

train2['shop_name'] = pd.Series(train2['shop_name'],dtype='category')
train2['item_name'] = pd.Series(train2['item_name'],dtype='category')
train2['item_category_name'] = pd.Series(train2['item_category_name'],dtype='category')

train2.dtypes
# Out:
# date_block_num           int32
# shop_id                  int32
# item_id                  int32
# item_category_id         int32
# shop_name             category
# item_name             category
# item_category_name    category
# sales                    int32
# dtype: object

# %%
#need to split in to many train validation sets, keep it simple and space *inefficient*
x_train_list = []
x_val_list = []
y_train_list = []
y_val_list = []


for val_month in range(21,34):
    
    val =   train2[train2['date_block_num']==val_month]
    val = val.merge(test0py,'right',on=['shop_id','item_id']).sort_values('ID')
    val['sales'] = val['sales'].fillna(0)
    
    train = train2[train2['date_block_num']<val_month]
    
    y_train = train['sales']
    x_train = train.drop('sales',axis=1)
    y_val = val['sales']
    x_val = val.drop('sales',axis=1)
    
    
    
    x_val_list.append(x_val)
    x_train_list.append(x_train)
    y_val_list.append(y_val)
    y_train_list.append(y_train)

# %%
x_val_list[0]
# Out:
#         date_block_num  shop_id  item_id  item_category_id  \
# 19759              NaN        5     5037               NaN
# 19760              NaN        5     5320               NaN
# 19761              NaN        5     5233               NaN
# 19762              NaN        5     5232               NaN
# 19763              NaN        5     5268               NaN
# 19764              NaN        5     5039               NaN
# 19765              NaN        5     5041               NaN
# 19766              NaN        5     5046               NaN
# 19767              NaN        5     5319               NaN
# 19768              NaN        5     5003               NaN
# 1062              21.0        5     4806              30.0
# 19769              NaN        5     4843               NaN
# 19770              NaN        5     4607               NaN
# 19771              NaN        5     4869               NaN
# 1063              21.0        5     4870              23.0
# 1064              21.0        5     4872              19.0
# 19772              NaN        5     4874               NaN
# 1059              21.0        5     4678              55.0
# 19773              NaN        5     4892               NaN
# 19774              NaN        5     4964               NaN
# 1061              21.0        5     4717              55.0
# 19775              NaN        5     5002               NaN
# 1090              21.0        5     5823              35.0
# 1086              21.0        5     5814              19.0
# 19776              NaN        5     5900               NaN
# 19777              NaN        5     5907               NaN
# 19778              NaN        5     5908               NaN
# 1080              21.0        5     5643               2.0
# 1081              21.0        5     5657               3.0
# 19779              NaN        5     5675               NaN
# ...                ...      ...      ...               ...
# 214170             NaN       45    14543               NaN
# 214171             NaN       45    19253               NaN
# 214172             NaN       45    17957               NaN
# 214173             NaN       45    12470               NaN
# 214174             NaN       45     7543               NaN
# 214175             NaN       45     6661               NaN
# 214176             NaN       45    11137               NaN
# 214177             NaN       45    11489               NaN
# 214178             NaN       45     9782               NaN
# 214179             NaN       45     2972               NaN
# 214180             NaN       45    19889               NaN
# 214181             NaN       45    20650               NaN
# 214182             NaN       45     5665               NaN
# 214183             NaN       45     9978               NaN
# 214184             NaN       45    10767               NaN
# 214185             NaN       45    14443               NaN
# 214186             NaN       45    14341               NaN
# 214187             NaN       45     5401               NaN
# 214188             NaN       45     9500               NaN
# 214189             NaN       45    16007               NaN
# 214190             NaN       45     3280               NaN
# 214191             NaN       45     4393               NaN
# 214192             NaN       45     4352               NaN
# 214193             NaN       45    18049               NaN
# 214194             NaN       45    18027               NaN
# 214195             NaN       45    18454               NaN
# 214196             NaN       45    16188               NaN
# 214197             NaN       45    15757               NaN
# 214198             NaN       45    19648               NaN
# 214199             NaN       45      969               NaN
#
#                      shop_name  \
# 19759                      NaN
# 19760                      NaN
# 19761                      NaN
# 19762                      NaN
# 19763                      NaN
# 19764                      NaN
# 19765                      NaN
# 19766                      NaN
# 19767                      NaN
# 19768                      NaN
# 1062    Вологда ТРЦ "Мармелад"
# 19769                      NaN
# 19770                      NaN
# 19771                      NaN
# 1063    Вологда ТРЦ "Мармелад"
# 1064    Вологда ТРЦ "Мармелад"
# 19772                      NaN
# 1059    Вологда ТРЦ "Мармелад"
# 19773                      NaN
# 19774                      NaN
# 1061    Вологда ТРЦ "Мармелад"
# 19775                      NaN
# 1090    Вологда ТРЦ "Мармелад"
# 1086    Вологда ТРЦ "Мармелад"
# 19776                      NaN
# 19777                      NaN
# 19778                      NaN
# 1080    Вологда ТРЦ "Мармелад"
# 1081    Вологда ТРЦ "Мармелад"
# 19779                      NaN
# ...                        ...
# 214170                     NaN
# 214171                     NaN
# 214172                     NaN
# 214173                     NaN
# 214174                     NaN
# 214175                     NaN
# 214176                     NaN
# 214177                     NaN
# 214178                     NaN
# 214179                     NaN
# 214180                     NaN
# 214181                     NaN
# 214182                     NaN
# 214183                     NaN
# 214184                     NaN
# 214185                     NaN
# 214186                     NaN
# 214187                     NaN
# 214188                     NaN
# 214189                     NaN
# 214190                     NaN
# 214191                     NaN
# 214192                     NaN
# 214193                     NaN
# 214194                     NaN
# 214195                     NaN
# 214196                     NaN
# 214197                     NaN
# 214198                     NaN
# 214199                     NaN
#
#                                                 item_name  \
# 19759                                                 NaN
# 19760                                                 NaN
# 19761                                                 NaN
# 19762                                                 NaN
# 19763                                                 NaN
# 19764                                                 NaN
# 19765                                                 NaN
# 19766                                                 NaN
# 19767                                                 NaN
# 19768                                                 NaN
# 1062      Medal of Honor: Warfighter [PC, русская версия]
# 19769                                                 NaN
# 19770                                                 NaN
# 19771                                                 NaN
# 1063              Minecraft [Xbox 360, английская версия]
# 1064    Minecraft. Playstation 3 Edition [PS3, русская...
# 19772                                                 NaN
# 1059                    MORRICONE ENNIO  The Very Best Of
# 19773                                                 NaN
# 19774                                                 NaN
# 1061    MY CHEMICAL ROMANCE  May Death Never Stop You ...
# 19775                                                 NaN
# 1090    Playstation Store пополнение бумажника: Карта ...
# 1086    Plants vs. Zombies Garden Warfare [PS3, русска...
# 19776                                                 NaN
# 19777                                                 NaN
# 19778                                                 NaN
# 1080    PS3: Контроллер игровой беспроводной черный (D...
# 1081    PS4: Гарнитура беспроводная черная для PS4 (с ...
# 19779                                                 NaN
# ...                                                   ...
# 214170                                                NaN
# 214171                                                NaN
# 214172                                                NaN
# 214173                                                NaN
# 214174                                                NaN
# 214175                                                NaN
# 214176                                                NaN
# 214177                                                NaN
# 214178                                                NaN
# 214179                                                NaN
# 214180                                                NaN
# 214181                                                NaN
# 214182                                                NaN
# 214183                                                NaN
# 214184                                                NaN
# 214185                                                NaN
# 214186                                                NaN
# 214187                                                NaN
# 214188                                                NaN
# 214189                                                NaN
# 214190                                                NaN
# 214191                                                NaN
# 214192                                                NaN
# 214193                                                NaN
# 214194                                                NaN
# 214195                                                NaN
# 214196                                                NaN
# 214197                                                NaN
# 214198                                                NaN
# 214199                                                NaN
#
#                          item_category_name      ID
# 19759                                   NaN       0
# 19760                                   NaN       1
# 19761                                   NaN       2
# 19762                                   NaN       3
# 19763                                   NaN       4
# 19764                                   NaN       5
# 19765                                   NaN       6
# 19766                                   NaN       7
# 19767                                   NaN       8
# 19768                                   NaN       9
# 1062          Игры PC - Стандартные издания      10
# 19769                                   NaN      11
# 19770                                   NaN      12
# 19771                                   NaN      13
# 1063                        Игры - XBOX 360      14
# 1064                             Игры - PS3      15
# 19772                                   NaN      16
# 1059    Музыка - CD локального производства      17
# 19773                                   NaN      18
# 19774                                   NaN      19
# 1061    Музыка - CD локального производства      20
# 19775                                   NaN      21
# 1090                     Карты оплаты - PSN      22
# 1086                             Игры - PS3      23
# 19776                                   NaN      24
# 19777                                   NaN      25
# 19778                                   NaN      26
# 1080                       Аксессуары - PS3      27
# 1081                       Аксессуары - PS4      28
# 19779                                   NaN      29
# ...                                     ...     ...
# 214170                                  NaN  214170
# 214171                                  NaN  214171
# 214172                                  NaN  214172
# 214173                                  NaN  214173
# 214174                                  NaN  214174
# 214175                                  NaN  214175
# 214176                                  NaN  214176
# 214177                                  NaN  214177
# 214178                                  NaN  214178
# 214179                                  NaN  214179
# 214180                                  NaN  214180
# 214181                                  NaN  214181
# 214182                                  NaN  214182
# 214183                                  NaN  214183
# 214184                                  NaN  214184
# 214185                                  NaN  214185
# 214186                                  NaN  214186
# 214187                                  NaN  214187
# 214188                                  NaN  214188
# 214189                                  NaN  214189
# 214190                                  NaN  214190
# 214191                                  NaN  214191
# 214192                                  NaN  214192
# 214193                                  NaN  214193
# 214194                                  NaN  214194
# 214195                                  NaN  214195
# 214196                                  NaN  214196
# 214197                                  NaN  214197
# 214198                                  NaN  214198
# 214199                                  NaN  214199
#
# [214200 rows x 8 columns]

# %%
#v = y_val_list[12]
#newval = val.merge(test0py,'right',on=['shop_id','item_id'])[['ID','sales']].sort_values('ID')
#newval.fillna(0,inplace=True)

# %%
#val_counts = train2['date_block_num'].value_counts()
#val_counts = val_counts.sort_index()
#val_counts

# %%
#np.cumsum(val_counts)

# %%
#x_train_list[0].shape
#should be 1107644

# %%
#x_val_list[0].shape
#should be 42595

# %%
#x_val_list[-1].shape
#should be 31531

# %%
#y_val_list[-1].shape
#should be 31531

# %%
#mvl = list()
#mvl.append(x_train_list)
#mvl.append(y_train_list)
#mvl.append(x_val_list)
#mvl.append(y_val_list)

# %%
#master_validation_list = mvl

# %%
import pickle

# %%
f = open('../../gen_data/master_validation_list.pickle','wb')
pickle.dump([x_train_list,y_train_list,x_val_list,y_val_list],f)
f.close()
