# %%
import pandas as pd
import numpy as np
import pickle

# %%
a = pickle.load(open('../gen_data/x_train--features2.ipynb--.pickle','rb'))

# %%
a[0].shape
# Out:
# (6186922, 58)

# %%
np.mean(a[0].item_name==0)
# Out:
# 0.8561693520623017

# %%
b = pickle.load(open('../gen_data/x_train--features3.ipynb--.pickle','rb'))

# %%
np.mean(b[0].item_name==0)
# Out:
# 0.5418877587148146

# %%
b[0].shape
# Out:
# (875578, 62)

# %%
c = pickle.load(open('../gen_data/x_train--features1.ipynb--.pickle','rb'))

# %%
c[0]
# Out:
#           date_block_num  shop_id  item_id  item_category_id  \
# 4488756               12        2       32              40.0
# 4488757               12        2       33              37.0
# 4488758               12        2       99              37.0
# 4488759               12        2      482              73.0
# 4488760               12        2      485              73.0
# 4488761               12        2      804              49.0
# 4488762               12        2      839              73.0
# 4488763               12        2     1007              67.0
# 4488764               12        2     1406              28.0
# 4488765               12        2     1407              19.0
# 4488766               12        2     1412              23.0
# 4488767               12        2     1413              19.0
# 4488768               12        2     1414              22.0
# 4488769               12        2     1415              20.0
# ...
