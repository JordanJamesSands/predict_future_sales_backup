# %%
import pandas as pd
import numpy as np
import pickle

# %%
x_train_list = pickle.load(open('../gen_data/x_train--features2.ipynb--.pickle','rb'))
x_test_list = pickle.load(open('../gen_data/x_test--features2.ipynb--.pickle','rb'))

sales = pd.read_csv('../gen_data/train1_cleaned.csv')

# %% [markdown]
# # downcast here, (actually just import downcasted sales data)

# %% [markdown]
# ### Generate time specific market price data

# %%
mean_price = sales.groupby(['date_block_num','item_id'],as_index=True).item_price.mean()
std_price = sales.groupby(['date_block_num','item_id'],as_index=True).item_price.std(ddof=1)
median_price = sales.groupby(['date_block_num','item_id'],as_index=True).item_price.median()

price_data = pd.concat([mean_price,std_price,median_price],axis=1)
price_data.columns = ['mean_prevmonth_item_price','std_prevmonth_item_price','median_prevmonth_item_price']
price_data.reset_index(inplace=True)
price_data['date_block_num'] += 1

# %% [markdown]
# ### Generate shop-time price data

# %%
#not gonna worry about getting median price by transaction, will 
#settle for median price by row (which could incnlude many transactions)
shop_item_data = sales.groupby(['date_block_num','shop_id','item_id'],as_index=False).item_price.median()
shop_item_data['date_block_num'] += 1
shop_item_data.columns = ['date_block_num','shop_id','item_id','median_prevmonth_shop_item_price']
shop_item_data.head()
# Out:
#    date_block_num  shop_id  item_id  median_prevmonth_shop_item_price
# 0               1        2       27                            2499.0
# 1               1        2       33                             499.0
# 2               1        2      317                             299.0
# 3               1        2      438                             299.0
# 4               1        2      471                             399.0

# %%
def merge_price_data(df):
    return df.merge(price_data,how='left').merge(shop_item_data,how='left')

# %%
x_train_list = list(map(merge_price_data,x_train_list))
x_test_list = list(map(merge_price_data,x_test_list))

# %%
def add_prop_median(df):
    df['prop_median_item_price'] = df.median_prevmonth_shop_item_price/df.median_prevmonth_item_price
    return df

# %%
x_train_list = list(map(add_prop_median,x_train_list))
x_test_list = list(map(add_prop_median,x_test_list))

# %% [markdown]
# ### consider deleting

# %%
#def insert_sd_above_market(df):
#    df['std_above_market'] = (df.mean_prevmonth_shop_item_price - df.mean_prevmonth_item_price) / df.std_prevmonth_item_price
#    return df

# %%
#def cleanup(df):
#    mean_sd = np.nanmean(df.std_prevmonth_item_price)
#    df['std_prevmonth_item_price'] = df.std_prevmonth_item_price.fillna(mean_sd)
#    df['std_above_market'] = df.std_above_market.fillna(0)
#    return df

# %%
#x_train_list = list(map(insert_sd_above_market,x_train_list))
#x_test_list = list(map(insert_sd_above_market,x_test_list))

# %%
#x_train_list = list(map(cleanup,x_train_list))
#x_test_list = list(map(cleanup,x_test_list))

# %% [markdown]
# ### end consider deleting

# %% [markdown]
# ### Save

# %%
pickle.dump(x_train_list,open('../gen_data/x_train--features3.ipynb--.pickle','wb'))
pickle.dump(x_test_list,open('../gen_data/x_test--features3.ipynb--.pickle','wb'))

# %%
x_train_list[1][x_train_list[1].item_id!=7019].prop_median_item_price.plot(kind='hist')

# %%
x_train_list[1].loc[2361416]
# Out:
# date_block_num                           19
# shop_id                                   6
# item_id                                7019
# item_category_id                         23
# sum_item_sales_back_1                    64
# sum_shop_sales_back_1                  2346
# item_cnt_month_back_1                     1
# sum_item_cat_sales_back_1              4461
# sum_item_cat_shop_sales_back_1           88
# sum_item_sales_back_2                     0
# sum_shop_sales_back_2                     0
# item_cnt_month_back_2                     0
# sum_item_cat_sales_back_2                 0
# sum_item_cat_shop_sales_back_2            0
# sum_item_sales_back_3                    51
# sum_shop_sales_back_3                  2304
# item_cnt_month_back_3                     1
# sum_item_cat_sales_back_3              4714
# sum_item_cat_shop_sales_back_3          108
# sum_item_sales_back_4                   228
# sum_shop_sales_back_4                  2587
# item_cnt_month_back_4                     8
# sum_item_cat_sales_back_4              4241
# sum_item_cat_shop_sales_back_4           94
# sum_item_sales_back_5                     0
# sum_shop_sales_back_5                     0
# item_cnt_month_back_5                     0
# sum_item_cat_sales_back_5                 0
# sum_item_cat_shop_sales_back_5            0
# sum_item_sales_back_6                     0
#                                      ...
# item_cnt_month_back_8                     0
# sum_item_cat_sales_back_8                 0
# sum_item_cat_shop_sales_back_8            0
# sum_item_sales_back_9                     0
# sum_shop_sales_back_9                     0
# item_cnt_month_back_9                     0
# sum_item_cat_sales_back_9                 0
# sum_item_cat_shop_sales_back_9            0
# sum_item_sales_back_10                    0
# sum_shop_sales_back_10                    0
# item_cnt_month_back_10                    0
# sum_item_cat_sales_back_10                0
# sum_item_cat_shop_sales_back_10           0
# sum_item_sales_back_11                    0
# sum_shop_sales_back_11                    0
# item_cnt_month_back_11                    0
# sum_item_cat_sales_back_11                0
# sum_item_cat_shop_sales_back_11           0
# sum_item_sales_back_12                    0
# sum_shop_sales_back_12                    0
# item_cnt_month_back_12                    0
# sum_item_cat_sales_back_12                0
# sum_item_cat_shop_sales_back_12           0
# month                                   aug
# numdays                                  31
# mean_prevmonth_item_price           228.439
# std_prevmonth_item_price            741.614
# median_prevmonth_item_price             0.5
# median_prevmonth_shop_item_price       2599
# prop_median_item_price                 5198
# Name: 2361416, Length: 71, dtype: object

# %% [markdown]
# ### clearly many 0.5 item prices are throwing this

# %%
x_train_list[1].sort_values('prop_median_item_price',ascending=False)[['date_block_num','shop_id','item_id','median_prevmonth_item_price','median_prevmonth_shop_item_price','prop_median_item_price']]
# Out:
#          date_block_num  shop_id  item_id  median_prevmonth_item_price  \
# 2361416              19        6     7019                         0.50
# 2431409              19       21     7019                         0.50
# 2548365              19       42     1851                         0.50
# 2603014              19       51     1856                         0.50
# 2603016              19       51     1858                         0.50
# 2571325              19       46     5243                         0.50
# 2514056              19       37     5241                         0.50
# 2615864              19       53     5241                         0.50
# 2342257              19        3     5243                         0.50
# 2603140              19       51     5243                         0.50
# 2418607              19       18     5036                         0.50
# 2419210              19       18     1837                         0.50
# 2367703              19        7     5036                         0.50
# 2343252              19        3     1836                         0.50
# 2425573              19       19     1837                         0.50
# 2654641              19       59     1837                         0.50
# 2424969              19       19     5035                         0.50
# 2393155              19       14     5036                         0.50
# 6425071                               NaN                     NaN
# 6425072                               NaN                     NaN
# 6425073                               NaN                     NaN
# 6425074                               NaN                     NaN
# 6425075                               NaN                     NaN
# 6425076                               NaN                     NaN
# 6425077                               NaN                     NaN
# 6425078                               NaN                     NaN
# 6425079                               NaN                     NaN
# 6425081                               NaN                     NaN
# 6425082                               NaN                     NaN
# 6425083                               NaN                     NaN
# 6425084                               NaN                     NaN
# 6425085                               NaN                     NaN
# 6425086                               NaN                     NaN
# 6425087                               NaN                     NaN
# 6425088                               NaN                     NaN
# 6425089                               NaN                     NaN
# 6425090                               NaN                     NaN
# 6425091                               NaN                     NaN
# 6425092                               NaN                     NaN
# 6425093                               NaN                     NaN
#
# [6425094 rows x 6 columns]

# %%
x_train_list[1][x_train_list[1].median_prevmonth_item_price!=0.5].median_prevmonth_item_price.plot(kind='hist')

# %% [markdown]
# ### titanfall is getting sold for 0.5 rubels a lot in month 18 for some reason

# %%
#shop 6
#sales[(sales.item_id==7019)].groupby('shop_id').item_price.mean()#[['shop_id','item_price']]
sales[(sales.date_block_num==15)&(sales.item_id==7019)][['date_block_num','shop_id','item_price']]
# Out:
#          date_block_num  shop_id  item_price
# 36364                15        2      1999.0
# 63552                15        3      2599.0
# 67253                15        4      1999.0
# 68893                15        4      2299.0
# 93433                15        4      2599.0
# 118630               15        5      2599.0
# 165856               15        6      2599.0
# 185466               15        6      2299.0
# 195510               15        6      2599.0
# 201872               15        6      1999.0
# 205176               15        6      1999.0
# 226234               15        7      1999.0
# 267823               15        7      1999.0
# 292494               15       11      2072.0
# 293653               15       11      2072.0
# 304581               15       11      2072.0
# 326924               15       12      1999.0
# 326959               15       12      1999.0
# 366547               15       14      1999.0
# 375312               15       14      2599.0
# 379424               15       14      2599.0
# 394983               15       14      1999.0
# 407145               15       15      2599.0
# 430095               15       15      2599.0
# 430289               15       15      1999.0
# 477846               15       16      2299.0
# 490969               15       16      2599.0
# 516507               15       17      1999.0
# 519560               15       17      2599.0
# 545441               15       18      2599.0
# ...                 ...      ...         ...
# 2187740              15       47      2599.0
# 2197659              15       47      2599.0
# 2207613              15       47      1999.0
# 2220022              15       48      2599.0
# 2235913              15       49      1999.0
# 2246733              15       49      2599.0
# 2248758              15       49      1999.0
# 2258154              15       50      2599.0
# 2262254              15       50      2599.0
# 2277595              15       50      2599.0
# 2312252              15       50      2599.0
# 2352746              15       51      2072.0
# 2368977              15       52      1999.0
# 2378722              15       52      2599.0
# 2428462              15       53      2599.0
# 2434695              15       53      2599.0
# 2502481              15       54      1999.0
# 2502533              15       54      2599.0
# 2541641              15       54      2599.0
# 2587454              15       54      2599.0
# 2646883              15       56      2299.0
# 2689506              15       56      1999.0
# 2707263              15       57      2599.0
# 2716121              15       57      1999.0
# 2722461              15       57      2599.0
# 2794774              15       57      2599.0
# 2801473              15       57      2599.0
# 2811198              15       57      2599.0
# 2816734              15       57      1999.0
# 2886564              15       58      1999.0
#
# [147 rows x 3 columns]
