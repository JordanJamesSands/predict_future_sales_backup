# %%
import pickle
import pandas as pd
import numpy as np

# %%
train_list = pickle.load(open('../gen_data/x_train--features3.ipynb--.pickle','rb'))
test_list = pickle.load(open('../gen_data/x_test--features3.ipynb--.pickle','rb'))

# %%
y_train_list = pickle.load(open('../gen_data/y_train--features1.ipynb--.pickle','rb'))

# %%
price_data = pd.read_csv('../gen_data/price_data_for_features3.csv')

# %%
#y_train_list_0_reset = y_train_list[0].reset_index().drop('index',axis=1).item_cnt_month

# %%
#train_list[0]['item_cnt_month'] = y_train_list_0_reset
train_list[0]['item_cnt_month'] = y_train_list[0]

# %%
train_list[0].head()
# Out:
#    date_block_num  shop_id  item_id  item_category_id  sum_item_sales_back_1  \
# 0              12        2       32              40.0                    0.0
# 1              12        2       33              37.0                   42.0
# 2              12        2       99              37.0                    0.0
# 3              12        2      482              73.0                   88.0
# 4              12        2      485              73.0                  111.0
#
#    sum_shop_sales_back_1  item_cnt_month_back_1  sum_item_cat_sales_back_1  \
# 0                    0.0                    0.0                        0.0
# 1                 1255.0                    1.0                     9906.0
# 2                    0.0                    0.0                        0.0
# 3                 1255.0                    1.0                      412.0
# 4                 1255.0                    1.0                      412.0
#
# ...

# %%
train_list[0][(train_list[0].date_block_num==32) & (train_list[0].item_id==21756)].item_cnt_month
# Out:
# 5971878    0.0
# 5976963    0.0
# 5982048    0.0
# 5987133    0.0
# 5992218    0.0
# 5997303    0.0
# 6002388    0.0
# 6007473    0.0
# 6012558    0.0
# 6017643    0.0
# 6022728    0.0
# 6027813    0.0
# 6032898    0.0
# 6037983    0.0
# 6043068    0.0
# 6048153    0.0
# 6053238    0.0
# 6058323    0.0
# 6063408    0.0
# 6068493    0.0
# 6073578    0.0
# 6078663    0.0
# 6083748    0.0
# 6088833    0.0
# 6093918    0.0
# 6099003    0.0
# 6104088    0.0
# 6109173    0.0
# 6114258    0.0
# 6119343    0.0
# 6124428    0.0
# 6129513    0.0
# 6134598    0.0
# 6139683    0.0
# 6144768    0.0
# 6149853    0.0
# 6154938    0.0
# 6160023    0.0
# 6165108    0.0
# 6170193    0.0
# 6175278    0.0
# 6180363    0.0
# 6185448    0.0
# Name: item_cnt_month, dtype: float32

# %%
price_data.tail(30)
# Out:
#         date_block_num  item_id  mean_prevmonth_item_price  \
# 228469            33.0  18758.0                      749.0
# 228470            33.0  18778.0                      299.0
# 228471            33.0  18779.0                      299.0
# 228472            33.0  18793.0                       49.0
# 228473            33.0  18832.0                       49.0
# 228474            33.0  18906.0                       28.0
# 228475            33.0  19978.0                     3199.0
# 228476            33.0  19981.0                      549.0
# 228477            33.0  19473.0                      249.0
# 228478            33.0  19178.0                      299.0
# 228479            33.0  19189.0                       98.0
# 228480            33.0  19247.0                       28.0
# 228481            33.0  20817.0                      479.0
# 228482            33.0  21680.0                       99.0
# 228483            33.0  21714.0                      399.0
# ...

# %%
train_list[0]
# Out:
#          date_block_num  shop_id  item_id  item_category_id  \
# 0                    12        2       32              40.0
# 1                    12        2       33              37.0
# 2                    12        2       99              37.0
# 3                    12        2      482              73.0
# 4                    12        2      485              73.0
# 5                    12        2      804              49.0
# 6                    12        2      839              73.0
# 7                    12        2     1007              67.0
# 8                    12        2     1406              28.0
# 9                    12        2     1407              19.0
# 10                   12        2     1412              23.0
# 11                   12        2     1413              19.0
# 12                   12        2     1414              22.0
# 13                   12        2     1415              20.0
# 14                   12        2     1416              23.0
# ...
